# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
n_pts = 500
np.random.seed(0)
Xa = np.array([np.random.normal(13, 2, n_pts),
               np.random.normal(12, 2, n_pts)]).T
Xb = np.array([np.random.normal(8, 2, n_pts),
               np.random.normal(6, 2, n_pts)]).T

X = np.vstack((Xa, Xb))
Y = np.matrix(np.append(np.zeros(n_pts), np.ones(n_pts))).T

# %%
plt.scatter(X[:n_pts, 0], X[:n_pts, 1])
plt.scatter(X[n_pts:, 0], X[n_pts:, 1])

# %%
model=Sequential()
model.add(Dense(units = 1, input_shape = (2,), activation='sigmoid'))
adam = Adam(lr = 0.1)
model.compile(adam, loss = 'binary_crossentropy', metrics = ['accuracy', 'MSE'])
h = model.fit(x = X, y = Y, verbose = 1, batch_size = 50, epochs = 40, shuffle = 'true' )
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/40
# 1000/1000 [==============================] - 0s 243us/step - loss: 1.4558 - acc: 0.5380 - mean_squared_error: 0.3680
# Epoch 2/40
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.6361 - acc: 0.6010 - mean_squared_error: 0.2249
# Epoch 3/40
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.4454 - acc: 0.8370 - mean_squared_error: 0.1380
# Epoch 4/40
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.3853 - acc: 0.8960 - mean_squared_error: 0.1132
# Epoch 5/40
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.3420 - acc: 0.9050 - mean_squared_error: 0.0957
# Epoch 6/40
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.3091 - acc: 0.9260 - mean_squared_error: 0.0832
# Epoch 7/40
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.2899 - acc: 0.9310 - mean_squared_error: 0.0769
# Epoch 8/40
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.2623 - acc: 0.9390 - mean_squared_error: 0.0676
# Epoch 9/40
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.2358 - acc: 0.9580 - mean_squared_error: 0.0577
# Epoch 10/40
# 1000/1000 [==============================] - 0s 35us/step - loss: 0.2202 - acc: 0.9630 - mean_squared_error: 0.0525
# Epoch 11/40
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.2049 - acc: 0.9580 - mean_squared_error: 0.0483
# Epoch 12/40
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.1935 - acc: 0.9600 - mean_squared_error: 0.0450
# Epoch 13/40
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.1815 - acc: 0.9670 - mean_squared_error: 0.0419
# Epoch 14/40
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.1722 - acc: 0.9670 - mean_squared_error: 0.0392
# Epoch 15/40
# 1000/1000 [==============================] - 0s 38us/step - loss: 0.1666 - acc: 0.9650 - mean_squared_error: 0.0382
# Epoch 16/40
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.1584 - acc: 0.9680 - mean_squared_error: 0.0359
# Epoch 17/40
# 1000/1000 [==============================] - 0s 35us/step - loss: 0.1505 - acc: 0.9690 - mean_squared_error: 0.0343
# Epoch 18/40
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.1453 - acc: 0.9670 - mean_squared_error: 0.0331
# Epoch 19/40
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.1395 - acc: 0.9760 - mean_squared_error: 0.0315
# Epoch 20/40
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.1340 - acc: 0.9740 - mean_squared_error: 0.0300
# Epoch 21/40
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.1317 - acc: 0.9740 - mean_squared_error: 0.0297
# Epoch 22/40
# 1000/1000 [==============================] - 0s 37us/step - loss: 0.1269 - acc: 0.9740 - mean_squared_error: 0.0289
# Epoch 23/40
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.1281 - acc: 0.9720 - mean_squared_error: 0.0305
# Epoch 24/40
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.1247 - acc: 0.9730 - mean_squared_error: 0.0288
# Epoch 25/40
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.1169 - acc: 0.9730 - mean_squared_error: 0.0268
# Epoch 26/40
# 1000/1000 [==============================] - 0s 39us/step - loss: 0.1123 - acc: 0.9790 - mean_squared_error: 0.0256
# Epoch 27/40
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.1106 - acc: 0.9750 - mean_squared_error: 0.0254
# Epoch 28/40
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.1097 - acc: 0.9780 - mean_squared_error: 0.0254
# Epoch 29/40
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.1082 - acc: 0.9750 - mean_squared_error: 0.0254
# Epoch 30/40
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.1034 - acc: 0.9780 - mean_squared_error: 0.0238
# Epoch 31/40
# 1000/1000 [==============================] - 0s 37us/step - loss: 0.1024 - acc: 0.9770 - mean_squared_error: 0.0238
# Epoch 32/40
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.1020 - acc: 0.9770 - mean_squared_error: 0.0238
# Epoch 33/40
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.1002 - acc: 0.9750 - mean_squared_error: 0.0235
# Epoch 34/40
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.0968 - acc: 0.9780 - mean_squared_error: 0.0229
# Epoch 35/40
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0948 - acc: 0.9770 - mean_squared_error: 0.0222
# Epoch 36/40
# 1000/1000 [==============================] - 0s 40us/step - loss: 0.0946 - acc: 0.9780 - mean_squared_error: 0.0225
# Epoch 37/40
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.0932 - acc: 0.9770 - mean_squared_error: 0.0222
# Epoch 38/40
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0921 - acc: 0.9780 - mean_squared_error: 0.0222
# Epoch 39/40
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.0944 - acc: 0.9760 - mean_squared_error: 0.0230
# Epoch 40/40
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0927 - acc: 0.9750 - mean_squared_error: 0.0226

# %%
plt.plot(h.history['acc'])
plt.title('accuracy')
plt.xlabel('epoch')
plt.legend('acc')
plt.show()

# %%
plt.plot(h.history['loss'])
plt.title('accuracy')
plt.xlabel('epoch')
plt.legend('loss')
plt.show()

# %%
def plot_decision_boundary(X,Y, model):
    x_span = np.linspace(min(X[:, 0])-1,max(X[:,0])+1)
    y_span = np.linspace(min(X[:, 1])-1,max(X[:,1])+1)
    xx, yy = np.meshgrid(x_span, y_span)
    xx_, yy_ = xx.ravel(), yy.ravel()
    grid = np.c_[xx_, yy_]
    pred_arr=model.predict(grid)
    z = pred_arr.reshape(xx.shape)
    plt.contourf(xx,yy,z)

# %%
plot_decision_boundary(X, y, model)
plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])
x = 7.5
y = 5
 
 
point = np.array([[x, y]])
prediction = model.predict(point)
plt.plot([x], [y], marker='o', markersize=10, color="blue")
print("prediction is: ",prediction)
# Out:
# prediction is:  [[0.99033314]]

# %%
dd
